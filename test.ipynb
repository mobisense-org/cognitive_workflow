# %%
# !pip3 install qai-hub
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !qai-hub configure --api_token rbfsjal4ihzjl6ecub88r63yd8rxh4eczgsg83x4
# Out:
# 2025-08-05 13:12:06.728 - INFO - Enabling verbose logging.
# /home/mobisense/Desktop/cognative_workflow/venv/lib/python3.10/site-packages/qai_hub/_cli.py:391: UserWarning: Overwriting configuration: /home/mobisense/.qai_hub/client.ini (previous configuration saved to /home/mobisense/.qai_hub/client.ini.bak)
#   warnings.warn(
# qai-hub configuration saved to /home/mobisense/.qai_hub/client.ini
# ==================== /home/mobisense/.qai_hub/client.ini ====================
# [api]
# api_token = rbfsjal4ihzjl6ecub88r63yd8rxh4eczgsg83x4
# api_url = https://app.aihub.qualcomm.com
# web_url = https://app.aihub.qualcomm.com
# verbose = True

# %%
import qai_hub as hub

# %%
hub.get_devices()
# Out:
# [Device(name='Google Pixel 3 (Family)', os='10', attributes=['os:android', 'framework:tflite', 'framework:onnx', 'abi:aarch64-android', 'vendor:google', 'format:phone', 'chipset:qualcomm-snapdragon-845', 'chipset:sdm845', 'hexagon:v65', 'soc-model:1']),
#  Device(name='Google Pixel 3', os='10', attributes=['os:android', 'framework:tflite', 'framework:onnx', 'abi:aarch64-android', 'vendor:google', 'format:phone', 'chipset:qualcomm-snapdragon-845', 'chipset:sdm845', 'hexagon:v65', 'soc-model:1']),
#  Device(name='Google Pixel 3a', os='10', attributes=['os:android', 'framework:tflite', 'framework:onnx', 'abi:aarch64-android', 'vendor:google', 'format:phone', 'chipset:qualcomm-snapdragon-670', 'chipset:sdm670', 'hexagon:v65', 'soc-model:6']),
# ...

# %%
hub.get_models()
# Out:
# [Model
#  -----
#  model_id    : mm6y7w12q
#  url         : https://app.aihub.qualcomm.com/models/mm6y7w12q/
#  name        : job_j5w3wmdjp_linked_bin
#  model_type  : QNN_CONTEXT_BINARY
#  producer_id : j5w3wmdjp
#  date        : 2025-07-01 18:57:54,
#  Model
#  -----
#  model_id    : mqy7o1z9q
#  url         : https://app.aihub.qualcomm.com/models/mqy7o1z9q/
#  name        : job_j5qr097mp_optimized_bin
#  model_type  : QNN_CONTEXT_BINARY
#  producer_id : j5qr097mp
#  date        : 2025-07-01 18:37:35,
#  Model
#  -----
#  model_id    : mn0v16zzm
#  url         : https://app.aihub.qualcomm.com/models/mn0v16zzm/
#  name        : job_jpewo4r0p_linked_bin
#  model_type  : QNN_CONTEXT_BINARY
#  producer_id : jpewo4r0p
#  date        : 2025-07-01 18:34:27,
#  Model
#  -----
#  model_id    : mnjgevdyn
#  url         : https://app.aihub.qualcomm.com/models/mnjgevdyn/
#  name        : job_j5qr097mp_aimet
#  model_type  : AIMET_ONNX
#  producer_id : j5qr097mp
# ...

# %%
whisper_decoder = hub.get_model("mnjgopwdn")
whisper_encoder = hub.get_model("mn1653xzq")

# %%
target_model
# Out:
# Model
# -----
# model_id    : mnjgopwdn
# url         : https://app.aihub.qualcomm.com/models/mnjgopwdn/
# name        : job_jgnl88ok5_optimized_onnx
# model_type  : ONNX
# producer_id : jgnl88ok5
# date        : 2025-06-24 18:10:22

# %%
# !python -m qai_hub_models.models.whisper_large_v3_turbo.export --target-runtime onnx --device "Snapdragon X Elite CRD" --skip-profiling --skip-inferencing
# Out:
# usage: export.py [-h] [--num-calibration-samples NUM_CALIBRATION_SAMPLES]
#                  [--target-runtime {qnn_context_binary,precompiled_qnn_onnx}]
#                  [--compile-options COMPILE_OPTIONS]
#                  [--profile-options PROFILE_OPTIONS] [--precision {float}]
# ...
